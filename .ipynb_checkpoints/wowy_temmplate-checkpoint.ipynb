# %%
import pandas as pd
import requests
#from graph import *
from scipy import stats
import string
import plotly.graph_objects as go
import math
import time


def wowy_shift(team_id,player1_id,seasons,ps = False, common = False):
    print(player1_id)
    print(team_id)
    print(seasons)
    print(ps)

    player_id = player1_id

    team_id = team_id
    
    if ps == False:
        s_type = 'Regular Season'
    elif ps == 'all':
        s_type = 'All'
    else:
        s_type = 'Playoffs'
                                  
    wowy_url = "https://api.pbpstats.com/get-wowy-stats/nba"
    wowy_params = {
        "0Exactly1OnFloor": player_id, # Player on
        "TeamId": team_id, # Golden State Warriors
        "Season": ",".join(seasons),
        "SeasonType": s_type,
        "Type": "Player", # Player stats,

    }
    wowy_response = requests.get(wowy_url, params=wowy_params)
    wowy = wowy_response.json()
    player_stats_on = wowy["multi_row_table_data"]
    wowy_url = "https://api.pbpstats.com/get-wowy-stats/nba"
    wowy_params = {
        "0Exactly0OnFloor": player_id,# Player on
        "TeamId": team_id, # Golden State Warriors
        "Season":  ",".join(seasons),
        "SeasonType": s_type,
        "Type": "Player", # Player stats,
    }
    #print(seasons)
    wowy_response = requests.get(wowy_url, params=wowy_params)
    wowy = wowy_response.json()
    player_stats_off = wowy["multi_row_table_data"]
    #print(rts)
   
    df = pd.DataFrame(player_stats_on)
    df['on'] = True
    df2 = pd.DataFrame(player_stats_off)
    df2['on'] = False

    combo = pd.concat([df,df2])




    return combo
index=pd.read_csv('data/index_master.csv')

# %%
combo

# %%
index.team.unique()

# %%
index.columns

# %%
import pandas as pd
import requests
import os
import time
from pathlib import Path
import logging
from typing import Set, Tuple
import sys

def test(team_id,player1_id,seasons,ps = False, common = False):
    player_id = player1_id

    team_id = team_id
    
    if ps == False:
        s_type = 'Regular Season'
    elif ps == 'all':
        s_type = 'All'
    else:
        s_type = 'Playoffs'
                                  
    wowy_url = "https://api.pbpstats.com/get-wowy-stats/nba"
    wowy_params = {
        "TeamId": team_id, # Golden State Warriors
        "Season": ",".join(seasons),
        "SeasonType": s_type,
        "Type": "Player", # Player stats,

    }
    wowy_response = requests.get(wowy_url, params=wowy_params)
    wowy = wowy_response.json()

    player_stats= wowy["multi_row_table_data"]
    print(len(player_stats))
    print(player_stats)
    df = pd.DataFrame(player_stats)
frame=test(1610612747,'2544',['2023-24'])
frame
# Out:
# {'single_row_table_data': {}, 'multi_row_table_data': [{'EntityId': '1626156', 'TeamId': '1610612747', 'Name': "D'Angelo Russell", 'ShortName': "D'Angelo Russell", 'RowId': '1626156', 'TeamAbbreviation': 'LAL', 'SecondsPlayed': 149052.2, 'Minutes': 2484, 'PlusMinus': 182, 'OffPoss': 5222, 'DefPoss': 5202, 'PenaltyOffPoss': 1109, 'PenaltyDefPoss': 699, 'SecondChanceOffPoss': 452, 'TotalPoss': 10424, 'AtRimFGM': 121, 'AtRimFGA': 174, 'SecondChanceAtRimFGM': 5, 'SecondChanceAtRimFGA': 8, 'PenaltyAtRimFGM': 12, 'PenaltyAtRimFGA': 23, 'ShortMidRangeFGM': 101, 'ShortMidRangeFGA': 254, 'LongMidRangeFGM': 44, 'LongMidRangeFGA': 107, 'Corner3FGM': 28, 'Corner3FGA': 73, 'SecondChanceCorner3FGM': 2, 'SecondChanceCorner3FGA': 5, 'PenaltyCorner3FGM': 4, 'PenaltyCorner3FGA': 11, 'Arc3FGM': 198, 'Arc3FGA': 472, 'SecondChanceArc3FGM': 13, 'SecondChanceArc3FGA': 35, 'PenaltyArc3FGM': 44, 'PenaltyArc3FGA': 107, 'FG2M': 266, 'FG2A': 535, 'FG3M': 226, 'FG3A': 545, 'FtPoints': 159, 'Points': 1369, 'OpponentPoints': 6050, 'SecondChanceFG2M': 12, 'SecondChanceFG2A': 27, 'SecondChanceFG3M': 15, 'SecondChanceFG3A': 40, 'SecondChanceFtPoints': 4, 'SecondChancePoints': 73, 'PenaltyFG2M': 36, 'PenaltyFG2A': 87, 'PenaltyFG3M': 48, 'PenaltyFG3A': 118, 'PenaltyFtPoints': 62, 'PenaltyPoints': 278, 'PtsAssisted2s': 204, 'PtsUnassisted2s': 328, 'PtsAssisted3s': 498, 'PtsUnassisted3s': 180, 'PtsPutbacks': 10, 'HeaveAttempts': 5, 'NonHeaveArc3FGA': 467, 'NonHeaveArc3FGM': 198, 'Fg2aBlocked': 35, 'TwoPtAssists': 335, 'ThreePtAssists': 147, 'Assists': 482, 'Arc3Assists': 107, 'Corner3Assists': 40, 'AtRimAssists': 231, 'ShortMidRangeAssists': 74, 'LongMidRangeAssists': 30, 'AssistPoints': 1111, 'OffThreePtRebounds': 10, 'OffTwoPtRebounds': 17, 'FTOffRebounds': 1, 'DefThreePtRebounds': 114, 'DefTwoPtRebounds': 91, 'FTDefRebounds': 3, 'DefRebounds': 208, 'OffRebounds': 28, 'Rebounds': 236, 'SelfOReb': 10, 'Steals': 69, 'BadPassSteals': 49, 'LostBallSteals': 20, 'LiveBallTurnovers': 103, 'BadPassOutOfBoundsTurnovers': 26, 'BadPassTurnovers': 80, 'DeadBallTurnovers': 53, 'LostBallOutOfBoundsTurnovers': 7, 'LostBallTurnovers': 23, 'StepOutOfBoundsTurnovers': 6, 'Travels': 2, 'Turnovers': 156, 'SecondChanceTurnovers': 3, 'PenaltyTurnovers': 28, 'ShootingFouls': 75, 'Fouls': 156, 'Loose Ball Fouls': 10, 'Offensive Fouls': 10, 'FoulsDrawn': 170, 'Charge Fouls Drawn': 2, 'Loose Ball Fouls Drawn': 2, 'Offensive Fouls Drawn': 18, 'FTA': 192, '2pt And 1 Free Throw Trips': 17, 'Technical Free Throw Trips': 13, 'TwoPtShootingFoulsDrawn': 72, 'ThreePtShootingFoulsDrawn': 4, 'NonShootingFoulsDrawn': 20, 'Blocked2s': 35, 'Blocked3s': 1, 'BlockedArc3': 1, 'BlockedAtRim': 14, 'BlockedLongMidRange': 3, 'BlockedShortMidRange': 18, 'Blocks': 36, 'RecoveredBlocks': 18, 'Defensive 3 Seconds Violations': 2, 'PenaltyPointsExcludingTakeFouls': 272, 'PenaltyOffPossExcludingTakeFouls': 1098, 'NonShootingPenaltyNonTakeFouls': 3, 'NonShootingPenaltyNonTakeFoulsDrawn': 17, 'Assisted2sPct': 0.38345864661654133, 'NonPutbacksAssisted2sPct': 0.39080459770114945, 'Assisted3sPct': 0.7345132743362832, 'Fg3Pct': 0.41467889908256883, 'SecondChanceFg3Pct': 0.375, 'PenaltyFg3Pct': 0.4067796610169492, 'NonHeaveFg3Pct': 0.4185185185185185, 'Fg2Pct': 0.497196261682243, 'SecondChanceFg2Pct': 0.4444444444444444, 'PenaltyFg2Pct': 0.41379310344827586, 'EfgPct': 0.5601851851851852, 'SecondChanceEfgPct': 0.5149253731343284, 'PenaltyEfgPct': 0.526829268292683, 'TsPct': 0.5867126833477135, 'SecondChanceTsPct': 0.5367647058823529, 'PenaltyTsPct': 0.5729166666666666, 'FG3APct': 0.5046296296296297, 'FG2APctBlocked': 0.06542056074766354, 'AtRimPctBlocked': 0.06321839080459771, 'ShortMidRangePctBlocked': 0.09055118110236221, 'LongMidRangePctBlocked': 0.009345794392523364, 'Usage': 22.893454038997216, 'LiveBallTurnoverPct': 0.6602564102564102, 'DefFTReboundPct': 0.034482758620689655, 'OffFTReboundPct': 0.009523809523809525, 'DefTwoPtReboundPct': 0.0674074074074074, 'OffTwoPtReboundPct': 0.013854930725346373, 'DefThreePtRebo ...

# %%
frame
